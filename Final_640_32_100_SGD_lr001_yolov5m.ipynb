# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16836, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 16836 (delta 1), reused 6 (delta 0), pack-reused 16825
# Receiving objects: 100% (16836/16836), 15.57 MiB | 11.24 MiB/s, done.
# Resolving deltas: 100% (11550/11550), done.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="R0xYmtI52bCnUHUWGq2P")
project = rf.workspace("chanara").project("final-tpjed")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 17.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Final-1 in yolov5pytorch:: 100%|██████████| 4869/4869 [00:00<00:00, 7173.39it/s]

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 32 --epochs 100 --data /content/Final-1/data.yaml --weights yolov5m.pt
# Out:
# 2024-08-04 06:29:27.854979: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-04 06:29:27.875141: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-04 06:29:27.881345: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from google.colab import files
# !zip -r Final_640_32_100_SGD_lr001_yolov5m.zip /content/yolov5/runs/train/exp2

files.download('Final_640_32_100_SGD_lr001_yolov5m.zip')
